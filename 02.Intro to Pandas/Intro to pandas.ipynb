# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Creating a dataframe from an array

# %% [markdown]
# ## Option 1

# %%
# creating an array
data = np.array([[1,4], [2,5], [3,6]])

# %%
# creating a dataframe
df = pd.DataFrame(data,
             index = ["row1","row2", "row3"],
             columns=["col1", "col2"])

# %%
# showing the data frame
df
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %% [markdown]
# ## Option 2

# %%
# creating an array with list shape
data2 = [[1,4], [2,5], [3,6]]

# %%
# creating a dataframe
df2 = pd.DataFrame(data2,
                  index = ["row1","row2", "row3"],
                  columns=["col1", "col2"])

# %%
# showing the dataframe
df2
# Out:
#       col1  col2
# row1     1     4
# row2     2     5
# row3     3     6

# %% [markdown]
# # Creating a DataFrame from a dictionary

# %%
# list used for this example
states = ["Texas", "Georgia", "Michigan","Florida"]

population = [12345678, 59874635, 8749587, 94536125]

# %%
# sorting lists within a dictionary
dict_states = {'States':states, 'Population':population}

# %%
# Creating the dataframe
df_states = pd.DataFrame(dict_states)

# %%
# Showing the dataframe
df_states
# Out:
#      States  Population
# 0     Texas    12345678
# 1   Georgia    59874635
# 2  Michigan     8749587
# 3   Florida    94536125

# %% [markdown]
# # Creating a DataFrame from a csv file

# %%
# Reading the csv file
df_exams = pd.read_csv('StudentsPerformance.csv')

# %%
# showing the 5 rows of dataframe 
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
# show dataframe
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
# show last 5 rows of dataframe
df_exams.tail()
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 995               completed          88             99             95
# 996                    none          62             55             55
# 997               completed          59             71             65
# 998               completed          68             78             77
# 999                    none          77             86             86

# %%
# show first n rows in dataframe
df_exams.head(7)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
# show last n rows in dataframe
df_exams.tail(8)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 994    male        group A                 high school      standard
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# 992                    none          55             76             76
# 993                    none          62             72             74
# 994                    none          63             63             62
# ...

# %%
# shape of dataframe
df_exams.shape
# Out:
# (1000, 8)

# %%
# size of dataframe
df_exams.size
# Out:
# 8000

# %%
# changing pandas behavior
pd.set_option('display.max_rows', 1000)
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %% [markdown]
# # Attributes

# %%
# get shape of a dataframe
df_exams.shape
# Out:
# (1000, 8)

# %%
#get index of dataframe
df_exams.index
# index range adds 1 for the header
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_exams.head(0)
# Out:
# Empty DataFrame
# Columns: [gender, race/ethnicity, parental level of education, lunch, test preparation course, math score, reading score, writing score]
# Index: []

# %%
# get column names
df_exams.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
df_exams.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %% [markdown]
# # Methods

# %%
# first 5 columns
df_exams.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %%
#show info of dataframe
df_exams.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %%
# describing basic stats of dataframe
df_exams.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %% [markdown]
# # Functions

# %%
# length of dataframe
len(df_exams)
# Out:
# 1000

# %%
# highest index of dataframe
max(df_exams.index)
# Out:
# 999

# %%
# lowest index of dataframe
min(df_exams.index)
# Out:
# 0

# %%
# type of dataframe
type(df_exams)
# Out:
# pandas.core.frame.DataFrame

# %%
# rounding the values of the dataset
round(df_exams,2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %% [markdown]
# # Selecting one column

# %% [markdown]
# ## Syntax 1

# %%
# select a column with []
df_exams['gender']
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
# 5      female
# 6      female
# 7        male
# 8        male
# 9      female
# 10       male
# 11       male
# 12     female
# 13       male
# 14     female
# 15     female
# 16       male
# 17     female
# 18       male
# 19     female
# 20       male
# 21     female
# 22       male
# 23     female
# 24       male
# 25       male
# 26       male
# 27     female
# 28       male
# 29     female
# 30     female
# 31     female
# 32     female
# 33       male
# 34       male
# 35       male
# 36     female
# 37     female
# 38     female
# 39       male
# 40       male
# 41     female
# 42     female
# 43       male
# 44     female
# 45       male
# 46     female
# 47     female
# 48     female
# 49       male
# 50       male
# 51       male
# 52       male
# 53       male
# 54     female
# 55     female
# 56     female
# 57       male
# 58       male
# 59     female
# 60       male
# 61       male
# ...

# %%
# type of series
type(df_exams['gender'])
# Out:
# pandas.core.series.Series

# %%
# series attributes and methods
df_exams['gender'].describe()
# Out:
# count       1000
# unique         2
# top       female
# freq         518
# Name: gender, dtype: object

# %%
df_exams['gender'].index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
df_exams['gender'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1000 entries, 0 to 999
# Series name: gender
# Non-Null Count  Dtype
# --------------  -----
# 1000 non-null   object
# dtypes: object(1)
# memory usage: 7.9+ KB

# %% [markdown]
# ## Syntax 2

# %%
# select a column with .
df_exams.gender
# Out:
# 0      female
# 1      female
# 2      female
# 3        male
# 4        male
# 5      female
# 6      female
# 7        male
# 8        male
# 9      female
# 10       male
# 11       male
# 12     female
# 13       male
# 14     female
# 15     female
# 16       male
# 17     female
# 18       male
# 19     female
# 20       male
# 21     female
# 22       male
# 23     female
# 24       male
# 25       male
# 26       male
# 27     female
# 28       male
# 29     female
# 30     female
# 31     female
# 32     female
# 33       male
# 34       male
# 35       male
# 36     female
# 37     female
# 38     female
# 39       male
# 40       male
# 41     female
# 42     female
# 43       male
# 44     female
# 45       male
# 46     female
# 47     female
# 48     female
# 49       male
# 50       male
# 51       male
# 52       male
# 53       male
# 54     female
# 55     female
# 56     female
# 57       male
# 58       male
# 59     female
# 60       male
# 61       male
# ...

# %%
df_exams['math score'].mean()
# Out:
# np.float64(66.089)

# %% [markdown]
# # Selecting two or more columns

# %%
# select two columns
df_exams[['gender', 'math score', 'reading score']]
# Out:
#      gender  math score  reading score
# 0    female          72             72
# 1    female          69             90
# 2    female          90             95
# 3      male          47             57
# 4      male          76             78
# 5    female          71             83
# 6    female          88             95
# 7      male          40             43
# 8      male          64             64
# 9    female          38             60
# 10     male          58             54
# 11     male          40             52
# 12   female          65             81
# 13     male          78             72
# 14   female          50             53
# 15   female          69             75
# 16     male          88             89
# 17   female          18             32
# 18     male          46             42
# 19   female          54             58
# 20     male          66             69
# 21   female          65             75
# 22     male          44             54
# ...

# %%
# check datatype
type(df_exams[['gender', 'math score']])
# Out:
# pandas.core.frame.DataFrame

# %%
# select more than 2 columns
df_exams[[ 'math score', 'reading score', 'writing score']]
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# 5            71             83             78
# 6            88             95             92
# 7            40             43             39
# 8            64             64             67
# 9            38             60             50
# 10           58             54             52
# 11           40             52             43
# 12           65             81             73
# 13           78             72             70
# 14           50             53             58
# 15           69             75             78
# 16           88             89             86
# 17           18             32             28
# 18           46             42             46
# ...

# %% [markdown]
# # Adding a new column

# %% [markdown]
# ## Adding a new column with a scalar value

# %%
# adding new column
df_exams['Language Score']=70

# %%
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %% [markdown]
# ## Adding a new column with an array

# %%
# create an array of 1000 elements
languageScoore = np.arange(0, 1000)

# %%
len(languageScoore)
# Out:
# 1000

# %%
# populating column with data
df_exams['Language Score'] = languageScoore[:len(df_exams)]
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
# create random int array
languageScoore = np.random.randint(0,101, size=(len(df_exams)))

# %%
df_exams["Language Score"] = languageScoore[:len(df_exams)]
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
# create random float array
print(np.random.uniform(0, 100, 20)
      )
# Out:
# [80.49063197 62.38350059 23.20685594 48.26037931 89.80618754 72.33201881
#  24.21905614 49.54307985 28.63164238  9.46997338 54.92948183 48.73984494
#   5.96653708 11.90075011 15.19139216  4.21476725 69.48815399 70.03807527
#  50.29759639 67.15152181]

# %% [markdown]
# # Adding a new column

# %% [markdown]
# ## assign()

# %%
# create random numbers
score1 = np.random.randint(0,101, size=(len(df_exams)))
score2 = np.random.randint(0, 101, size=(len(df_exams)))

# %%
# create series 
series1 = pd.Series(score1)
series2 = pd.Series(score2)

# %%
series2
# Out:
# 0      100
# 1       11
# 2       27
# 3        6
# 4       19
# 5        6
# 6       74
# 7       21
# 8       51
# 9       50
# 10      13
# 11      42
# 12      78
# 13      24
# 14      94
# 15      64
# 16      13
# 17      94
# 18      44
# 19      27
# 20       1
# 21      65
# 22      80
# 23      23
# 24      46
# 25       1
# 26      42
# 27      54
# 28      82
# 29       1
# 30      88
# 31      49
# 32      99
# 33       2
# 34      27
# 35      40
# 36      14
# 37      20
# 38     100
# 39      34
# 40      70
# 41      99
# 42      43
# 43      34
# 44      35
# 45      67
# 46      85
# 47      38
# 48      22
# 49      34
# 50      74
# 51      56
# 52      94
# 53      33
# 54      76
# 55      23
# 56      93
# 57      96
# 58      39
# 59       6
# 60      53
# 61      86
# 62      20
# 63       4
# 64      38
# 65       2
# 66      68
# 67      65
# 68      24
# 69      98
# 70      60
# 71      50
# 72      39
# 73      56
# 74      12
# 75      38
# ...

# %%
df_exams.assign(score1=series1, score2=series2)
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %%
df_exams = df_exams.assign(score1=series1, score2=series2)
df_exams
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# 5    female        group B          associate's degree      standard
# 6    female        group B                some college      standard
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 10     male        group C          associate's degree      standard
# 11     male        group D          associate's degree      standard
# 12   female        group B                 high school      standard
# ...

# %% [markdown]
# ## insert()

# %%
# using insert() to add column
df_exams.insert(2, "test", series1)

# %%
df_exams
# Out:
#      gender race/ethnicity  test parental level of education         lunch  \
# 0    female        group B    63           bachelor's degree      standard
# 1    female        group C    80                some college      standard
# 2    female        group B    20             master's degree      standard
# 3      male        group A    32          associate's degree  free/reduced
# 4      male        group C    52                some college      standard
# 5    female        group B    15          associate's degree      standard
# 6    female        group B    67                some college      standard
# 7      male        group B    73                some college  free/reduced
# 8      male        group D     8                 high school  free/reduced
# 9    female        group B   100                 high school  free/reduced
# 10     male        group C    81          associate's degree      standard
# ...

# %% [markdown]
# # Math Operations

# %% [markdown]
# ## Operations in columns

# %%
# select a column and sum
df_exams['math score'].sum()
# Out:
# np.int64(66089)

# %%
# count, mean, std, max, min
print(df_exams['math score'].count(),
      df_exams['math score'].mean(),
      df_exams['math score'].std(),
      df_exams['math score'].max(),
      df_exams['math score'].min())
# Out:
# 1000 66.089 15.16308009600945 100 0

# %%
df_exams.describe()
# Out:
#               test  math score  reading score  writing score  Language Score  \
# count  1000.000000  1000.00000    1000.000000    1000.000000      1000.00000
# mean     50.327000    66.08900      69.169000      68.054000        49.68600
# std      29.858761    15.16308      14.600192      15.195657        28.79487
# min       0.000000     0.00000      17.000000      10.000000         0.00000
# 25%      24.000000    57.00000      59.000000      57.750000        23.00000
# 50%      50.000000    66.00000      70.000000      69.000000        51.00000
# 75%      77.000000    77.00000      79.000000      79.000000        73.25000
# max     100.000000   100.00000     100.000000     100.000000       100.00000
#
#             score1       score2
# count  1000.000000  1000.000000
# mean     50.327000    49.805000
# std      29.858761    29.446291
# min       0.000000     0.000000
# 25%      24.000000    24.750000
# 50%      50.000000    50.000000
# 75%      77.000000    75.000000
# ...

# %% [markdown]
# ## Operations in rows

# %%
# calculating the sum in a row
df_exams['math score'] + df_exams['reading score'] + df_exams['writing score']
# Out:
# 0      218
# 1      247
# 2      278
# 3      148
# 4      229
# 5      232
# 6      275
# 7      122
# 8      195
# 9      148
# 10     164
# 11     135
# 12     219
# 13     220
# 14     161
# 15     222
# 16     263
# 17      78
# 18     134
# 19     173
# 20     198
# 21     210
# 22     151
# 23     215
# 24     225
# 25     219
# 26     178
# 27     211
# 28     205
# 29     207
# 30     217
# 31     189
# 32     193
# 33     120
# 34     266
# 35     241
# 36     238
# 37     173
# 38     253
# 39     170
# 40     170
# 41     199
# 42     176
# 43     190
# 44     160
# 45     176
# 46     182
# 47     213
# 48     207
# 49     248
# 50     156
# 51     214
# 52     139
# 53     241
# 54     242
# 55     117
# 56     253
# 57     156
# 58     175
# 59      27
# 60     225
# 61     112
# 62     178
# 63     220
# 64     176
# 65     192
# 66     119
# 67     206
# 68     175
# 69     160
# 70     194
# 71     181
# 72     140
# 73     174
# 74     139
# 75     123
# ...

# %%
# calculating the average score
df_exams['average score'] = (df_exams['math score'] + df_exams['reading score'] + df_exams['writing score']) / 3
df_exams.round(2)
# Out:
#      gender race/ethnicity  test parental level of education         lunch  \
# 0    female        group B    63           bachelor's degree      standard
# 1    female        group C    80                some college      standard
# 2    female        group B    20             master's degree      standard
# 3      male        group A    32          associate's degree  free/reduced
# 4      male        group C    52                some college      standard
# 5    female        group B    15          associate's degree      standard
# 6    female        group B    67                some college      standard
# 7      male        group B    73                some college  free/reduced
# 8      male        group D     8                 high school  free/reduced
# 9    female        group B   100                 high school  free/reduced
# 10     male        group C    81          associate's degree      standard
# ...
